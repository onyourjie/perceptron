# %% [markdown]
# # Perceptron

# %% [markdown]
# ## Fungsi-fungsi *Plotting*
#
# Jangan mengubah kode pada *cell* di bawah ini.

# %%
import matplotlib.pyplot as plt
import numpy as np

def line(w, th=0):
    w2 = w[2] + .001 if w[2] == 0 else w[2]

    return lambda x: (th - w[1] * x - w[0]) / w2


def plot(f1, f2, X, target, padding=1, marker='o'):
    X = np.array(X)

    x_vals, y_vals = X[:, 1], X[:, 2]
    xmin, xmax, ymin, ymax = x_vals.min(), x_vals.max(), y_vals.min(), y_vals.max()
    markers = f'r{marker}', f'b{marker}'
    line_x = np.arange(xmin-padding-1, xmax+padding+1)

    for c, v in enumerate(np.unique(target)):
        p = X[np.where(target == v)]

        plt.plot(p[:,1], p[:,2], markers[c])

    plt.axis([xmin-padding, xmax+padding, ymin-padding, ymax+padding])
    plt.plot(line_x, f1(line_x))
    plt.plot(line_x, f2(line_x))
    plt.show()

# %% [markdown]
# ## Praktikum

# %% [markdown]
# ### a) Fungsi *Step* Perceptron
#
# Tulis kode ke dalam *cell* di bawah ini:

# %%
def percep_step(input, th=0):
	return 1 if input > th else -1 if input < -th else 0

# %% [markdown]
# ### b) Fungsi *training* Perceptron
#
# Tulis kode ke dalam *cell* di bawah ini:

# %%
def percep_fit(X, target, th=0, a=1, max_epoch=-1, verbose=False, draw=False, marker='o'):
	w = np.zeros(len(X[0]) + 1)
	bias = np.ones((len(X), 1))
	X = np.hstack((bias, X))
	stop = False
	epoch = 0
	while not stop and (max_epoch == -1 or epoch < max_epoch):
		stop = True
		epoch += 1
		if verbose:
			print('\nEpoch', epoch)
		for r, row in enumerate(X):
			y_in = np.dot(row, w)
			y = percep_step(y_in, th)
			if y != target[r]:
				stop = False
				w = [w[i] + a * target[r] * row[i] for i in range(len(row))]
		if verbose:
			print('Bobot:', w)
		if draw:
			plot(line(w, th), line(w, -th), X, target, marker=marker)

	return w, epoch

# %% [markdown]
# ### c) Fungsi *testing* Perceptron
#
# Tulis kode ke dalam *cell* di bawah ini:

# %%
def percep_predict(X, w, th=0):
	Y = []
	for x in X:
		y_in = w[0] + np.dot(x, w[1:])
		y = percep_step(y_in, th)
		Y.append(y)
	return Y

# %% [markdown]
# ### d) Fungsi Hitung Akurasi
#
# Tulis kode ke dalam *cell* di bawah ini:

# %%
def calc_accuracy(a, b):
	s = [1 if a[i] == b[i] else 0 for i in range(len(a))]
	return sum(s) / len(a)

# %% [markdown]
# ### e) Logika AND
#
# Tulis kode ke dalam *cell* di bawah ini:

# %%
import numpy as np

train = (1, 1), (1, -1), (-1, 1), (-1, -1)
target = 1, -1, -1, -1
th = .2
model, epoch = percep_fit(train, target, th, verbose=True, draw=True)
output = percep_predict(train, model)
accuracy = calc_accuracy(output, target)
print('Epochs:', epoch)
print('Output:', output)
print('Target:', target)
print('Accuracy:', accuracy)
# Out:
# Epoch 1
# Bobot: [np.float64(-1.0), np.float64(1.0), np.float64(1.0)]
# Epoch 2
# Bobot: [np.float64(-1.0), np.float64(1.0), np.float64(1.0)]
# Epochs: 2
# Output: [1, -1, -1, -1]
# Target: (1, -1, -1, -1)
# Accuracy: 1.0

# %% [markdown]
# ### f) Logika OR
#
# Tulis kode ke dalam *cell* di bawah ini:

# %%
train = (1, 1), (1, -1), (-1, 1), (-1, -1)
target = 1, 1, 1, -1
th = .2
model, epoch = percep_fit(train, target, th, verbose=True,
draw=True)
output = percep_predict(train, model)
accuracy = calc_accuracy(output, target)

28

print('Epochs:', epoch)
print('Output:', output)
print('Target:', target)
print('Accuracy:', accuracy)
# Out:
# Epoch 1
# Bobot: [np.float64(1.0), np.float64(1.0), np.float64(1.0)]
# Epoch 2
# Bobot: [np.float64(1.0), np.float64(1.0), np.float64(1.0)]
# Epochs: 2
# Output: [1, 1, 1, -1]
# Target: (1, 1, 1, -1)
# Accuracy: 1.0

# %% [markdown]
# ### g) Logika AND NOT
#
# Tulis kode ke dalam *cell* di bawah ini:

# %%
train = (1, 1), (1, -1), (-1, 1), (-1, -1)
target = -1, 1, -1, -1
th = .2
model, epoch = percep_fit(train, target, th, verbose=True,
draw=True)
output = percep_predict(train, model)
accuracy = calc_accuracy(output, target)
print('Epochs:', epoch)
print('Output:', output)
print('Target:', target)
print('Accuracy:', accuracy)
# Out:
# Epoch 1
# Bobot: [np.float64(-1.0), np.float64(1.0), np.float64(-1.0)]
# Epoch 2
# Bobot: [np.float64(-1.0), np.float64(1.0), np.float64(-1.0)]
# Epochs: 2
# Output: [-1, 1, -1, -1]
# Target: (-1, 1, -1, -1)
# Accuracy: 1.0

# %% [markdown]
# ### f) Logika XOR
#
# Tulis kode ke dalam *cell* di bawah ini:

# %%
train = (1, 1), (1, -1), (-1, 1), (-1, -1)
target = -1, 1, 1, -1
th = .2
model, epoch = percep_fit(train, target, th, max_epoch=50,
verbose=True, draw=False)
output = percep_predict(train, model)
accuracy = calc_accuracy(output, target)
print('Output:', output)
print('Accuracy:', accuracy)
# Out:
# Epoch 1
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 2
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 3
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 4
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 5
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 6
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 7
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 8
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 9
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 10
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 11
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 12
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 13
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 14
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 15
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 16
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 17
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 18
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 19
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 20
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 21
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 22
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 23
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 24
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 25
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 26
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 27
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 28
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 29
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 30
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 31
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 32
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 33
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 34
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 35
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 36
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 37
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 38
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 39
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 40
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 41
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 42
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 43
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 44
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 45
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 46
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 47
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 48
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 49
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
#
# Epoch 50
# Bobot: [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Output: [0, 0, 0, 0]
# Accuracy: 0.0

# %% [markdown]
# ## *Dataset* Iris
#
# ![Iris Dataset](https://www.spataru.at/images/blog/iris-dataset-svm/iris_types.jpg)

# %% [markdown]
# ### h) *Load* dan *plot* data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset('iris')

sns.pairplot(iris, hue='species')
plt.show()

# %% [markdown]
# ### i) Menghapus Kelas Virginica

# %%
iris = iris.loc[iris['species'] != 'virginica']

sns.pairplot(iris, hue='species')
plt.show()

# %% [markdown]
# ### j) Menghapus ciri `sepal_width` dan `petal_width`

# %%
iris = iris.drop(['sepal_width', 'petal_width'], axis=1)

sns.pairplot(iris, hue='species')
plt.show()

# %% [markdown]
# ### k) Proses *Training* dan *Testing*

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import minmax_scale

X = iris[['sepal_length', 'petal_length']].to_numpy()
X = minmax_scale(X)

y = iris['species'].to_numpy()
c = {'setosa': -1, 'versicolor': 1}
y = [c[i] for i in y]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)
w, epoch = percep_fit(X_train, y_train, verbose=True, draw=True, marker='.')
out = percep_predict(X_test, w)
accuracy = calc_accuracy(out, y_test)

print('Epochs:', epoch)
print('Accuracy:', accuracy)
# Out:
# Epoch 1
# Bobot: [np.float64(-1.0), np.float64(0.444444444444444), np.float64(2.1219512195121952)]
# Epoch 2
# Bobot: [np.float64(-1.0), np.float64(0.444444444444444), np.float64(2.1219512195121952)]
# Epochs: 2
# Accuracy: 1.0
